# %% [markdown]
# # Detecting Topic Merges and Splits in Dynamic Political Conversations
#
# Cláudia Oliveira
#
# Supervisor - Prof. Dr. Álvaro Figueira
#
# Faculty of Science, University of Porto

# %%
import pandas as pd
import re
from functions import *
import ast

# %%
tweets = pd.read_csv("datasets/cleanedtweets.csv", encoding="utf-8", low_memory=False)
lda = pd.read_csv("datasets/lda.csv", encoding="utf-8", low_memory=False)
nmf = pd.read_csv("datasets/nmf.csv", encoding="utf-8", low_memory=False)
bertopic = pd.read_csv("datasets/bertopic.csv", encoding="utf-8", low_memory=False)

# %% [markdown]
# ### LDA

# %%
plot_static_metrics(lda, "LDA")

# %%
summarize_static_metrics(lda,"LDA")
# Out:
# === LDA Overall Metrics Summary ===
# Average Coherence: 0.5792
# Average Diversity: 0.9646
# Average Topic Quality (TQ): 0.5586

# %% [markdown]
# ### NMF

# %%
plot_static_metrics(nmf, "NMF")

# %%
summarize_static_metrics(nmf,"NMF")
# Out:
# === NMF Overall Metrics Summary ===
# Average Coherence: 0.7730
# Average Diversity: 0.9785
# Average Topic Quality (TQ): 0.7565
